# %%
from models.HTModel_fixed import HTModel_fixed
import numpy as np

# %%
N = 4
M = 2
ranks = [12, 24]
Y = 10
X = np.random.randn(N, 49) # Input data X has the shape (N, s)
HT = HTModel_fixed(N, M, ranks, Y)
h = HT.forward(X)
print(h)
# Out:
# [  314172.53463552 -1297730.11699004 -1533801.00535052  -347883.95003003
#   3636766.26016112 -1483925.57160638 -1144416.63965753  -133151.77390087
#   1010633.5619822  -1353808.20984283]
