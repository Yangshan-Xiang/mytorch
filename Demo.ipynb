# %%
from models.HTModel import HTModel
import numpy as np

# %%
N = 4
M = 2
ranks = [12, 24]
Y = 10
X = np.random.randn(N, 49) # Input data X has the shape (N, s)
HT = HTModel(N, M, ranks, Y)
h = HT.forward(X)
print(h)
# Out:
# [ 31166.11947416  77843.50845895  45874.41455727  16202.61440641
#  -10896.56727506 -40811.98378559   9895.16518893 -17119.7407725
#   57402.83835358 -10078.6892589 ]
