# %%
from models.HTModelFixed import HTModelFixed
import numpy as np

# %%
N = 4
M = 2
ranks = [12, 24]
Y = 10
F = np.random.randn(N, M)
HT = HTModelFixed(N, M, Y, ranks)
h = HT.forward(F)
print(h.shape)
# Out:
# (10,)
