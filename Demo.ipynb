# %%
from models.HTModel import HTModel
import torch

# %%
# Example for HTModel
batch_size = 64
N = 4
s = 3
M = 2
ranks = [12, 24]
Y = 10
X = torch.randn(batch_size, N, s)
HT = HTModel(N, s, M, Y, ranks)
h = HT(X)
print(h.shape)
# Out:
# torch.Size([64, 10])
